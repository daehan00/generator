# %%
from unknown_data.test import TestHelper
from unknown_data import Config_db, Category

db_config = Config_db(
    dbms="postgresql",
    username="forensic_agent",
    password="0814",
    ip="13.124.25.47",
    port=5432,
    database_name="forensic_agent"
)

helper = TestHelper(db_config)

# helper.get_task_ids()

# %%
import datetime
import uuid

def category_make_test_artifacts(task_id: str, category: Category, artifact_list: list) -> int:
    data = helper.get_encoded_results(task_id, category)

    white_list = ["urls", "visits", "visited_links", "keywords", "keywork_search_terms", "autofill", "downloads", "download_url_chains", "logins"]
    white_list_set = set()
    for i in white_list:
        white_list_set.update(("chrome."+i, "edge."+i))

    cnt = 0
    for d in data.data:
        artifact_type = d.name.lower()

        if category == Category.BROWSER and artifact_type not in white_list_set:
            continue

        collected_at = datetime.datetime.now(tz=datetime.UTC)
        collected_at_str = collected_at.isoformat()
        
        # to_dict('records')를 사용하여 한 번에 모든 행을 딕셔너리 리스트로 변환 (훨씬 빠름!)
        records = d.data.to_dict('records')
        
        # 리스트 컴프리헨션으로 artifacts 생성 (for 루프보다 빠름)
        artifacts = [
            {
                "id": str(uuid.uuid4()),
                "artifact_type": artifact_type,
                "source": None,
                "data": record,
                "collected_at": collected_at_str
            }
            for record in records
        ]
        
        artifact_list.extend(artifacts)
        len_records = len(records)
        cnt += len_records
        # print(f"    {artifact_type}: {len_records}개 행 추가됨")
    del data
    return cnt

def make_test_artifacts(task_id: str) -> list:
    artifact_list = []

    for category in Category:
        # print(f"현재 {len(artifact_list)}개 아티팩트 존재.")
        cnt = category_make_test_artifacts(task_id, category, artifact_list)
        # print(f"{category.name}: {cnt}개 추가.")

    print(f"총 {len(artifact_list)}개의 artifact 생성됨\n")
    return artifact_list

# %%
task_ids = helper.get_task_ids()
# Out:
# === 데이터베이스 Task 정보 ===
# 총 고유 Task 수: 8
#
# Task ID: session-20251002-052932-151e52e9
#   생성 시간 (최초): 2025-10-02 14:29:32 KST
#   데이터 개수: 6
#   모듈별 분포:
#     - BROWSER_DATA: 1개
#     - DELETED_FILES: 1개
#     - LNK_DATA: 1개
#     - MESSENGER_DATA: 1개
#     - PREFETCH_DATA: 1개
#     - USB_DATA: 1개
#
# Task ID: session-20251002-051704-b6c68cbb
#   생성 시간 (최초): 2025-10-02 14:17:04 KST
#   데이터 개수: 6
#   모듈별 분포:
#     - BROWSER_DATA: 1개
#     - DELETED_FILES: 1개
#     - LNK_DATA: 1개
#     - MESSENGER_DATA: 1개
#     - PREFETCH_DATA: 1개
#     - USB_DATA: 1개
#
# Task ID: session-20251002-050523-6de09ba4
#   생성 시간 (최초): 2025-10-02 14:05:23 KST
#   데이터 개수: 5
#   모듈별 분포:
#     - BROWSER_DATA: 1개
#     - LNK_DATA: 1개
#     - MESSENGER_DATA: 1개
#     - PREFETCH_DATA: 1개
#     - USB_DATA: 1개
#
# Task ID: session-20251002-045744-53bf2115
#   생성 시간 (최초): 2025-10-02 13:57:44 KST
#   데이터 개수: 6
#   모듈별 분포:
#     - BROWSER_DATA: 1개
#     - DELETED_FILES: 1개
#     - LNK_DATA: 1개
#     - MESSENGER_DATA: 1개
#     - PREFETCH_DATA: 1개
#     - USB_DATA: 1개
#
# Task ID: session-20251002-040520-28a9dc6c
#   생성 시간 (최초): 2025-10-02 13:05:20 KST
#   데이터 개수: 6
#   모듈별 분포:
#     - USB_DATA: 1개
#     - BROWSER_DATA: 1개
#     - MESSENGER_DATA: 1개
#     - PREFETCH_DATA: 1개
#     - LNK_DATA: 1개
#     - DELETED_FILES: 1개
#
# Task ID: session-20251001-151642-1ff9e24a
#   생성 시간 (최초): 2025-10-02 00:16:42 KST
#   데이터 개수: 6
#   모듈별 분포:
#     - USB_DATA: 1개
#     - BROWSER_DATA: 1개
#     - MESSENGER_DATA: 1개
#     - PREFETCH_DATA: 1개
#     - LNK_DATA: 1개
#     - DELETED_FILES: 1개
#
# Task ID: session-20250930-133411-99e3becc
#   생성 시간 (최초): 2025-09-30 22:34:11 KST
#   데이터 개수: 6
#   모듈별 분포:
#     - USB_DATA: 1개
#     - BROWSER_DATA: 1개
#     - MESSENGER_DATA: 1개
#     - PREFETCH_DATA: 1개
#     - LNK_DATA: 1개
#     - DELETED_FILES: 1개
#
# Task ID: session-20250930-060607-59984faf
#   생성 시간 (최초): 2025-09-30 15:06:07 KST
#   데이터 개수: 6
#   모듈별 분포:
#     - USB_DATA: 1개
#     - BROWSER_DATA: 1개
#     - MESSENGER_DATA: 1개
#     - PREFETCH_DATA: 1개
#     - LNK_DATA: 1개
#     - DELETED_FILES: 1개

# %%
for task_id in task_ids:
    if task_id == "session-20251002-050523-6de09ba4":
        continue
    print("task_id:", task_id)
    result = make_test_artifacts(task_id)
    print(f"total artifacts: {len(result)}")
    del result
# Out:
# task_id: session-20251002-052932-151e52e9
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit insecure_credentials.create_time to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:46:36] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit insecure_credentials.create_time to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit logins.date_last_filled to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:46:37] DataEncoder - Converted WebKit keywords.last_modified to datetime
# 총 110657개의 artifact 생성됨
#
# total artifacts: 110657
# task_id: session-20251002-051704-b6c68cbb
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_last_filled to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit insecure_credentials.create_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_last_filled to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit insecure_credentials.create_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_last_filled to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted WebKit logins.date_last_filled to datetime
# [2025-10-13 11:47:17] DataEncoder - Cookies failed
# [2025-10-13 11:47:17] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:47:17] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:47:18] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:47:18] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:47:18] DataEncoder - Converted WebKit keywords.last_modified to datetime
# 총 83490개의 artifact 생성됨
#
# total artifacts: 83490
# task_id: session-20251002-045744-53bf2115
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit logins.date_last_filled to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit insecure_credentials.create_time to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit logins.date_last_filled to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit logins.date_last_filled to datetime
# [2025-10-13 11:47:39] DataEncoder - Cookies failed
# [2025-10-13 11:47:39] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:47:39] DataEncoder - Converted WebKit keywords.last_modified to datetime
# 총 96862개의 artifact 생성됨
#
# total artifacts: 96862
# task_id: session-20251002-040520-28a9dc6c
# [2025-10-13 11:47:44] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:47:44] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:47:44] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:47:44] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:47:44] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:47:44] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:47:44] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:47:44] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:47:44] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:47:44] DataEncoder - Converted WebKit logins.date_last_filled to datetime
# [2025-10-13 11:47:44] DataEncoder - Cookies failed
# [2025-10-13 11:47:44] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:47:44] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:47:44] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:47:44] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:47:44] DataEncoder - Converted WebKit keywords.last_modified to datetime
# 총 7592개의 artifact 생성됨
#
# total artifacts: 7592
# task_id: session-20251001-151642-1ff9e24a
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit logins.date_last_filled to datetime
# [2025-10-13 11:47:48] DataEncoder - Cookies failed
# [2025-10-13 11:47:48] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:47:48] DataEncoder - Converted WebKit keywords.last_modified to datetime
# 총 30022개의 artifact 생성됨
#
# total artifacts: 30022
# task_id: session-20250930-133411-99e3becc
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:47:55] DataEncoder - Converted WebKit keywords.last_modified to datetime
# 총 22450개의 artifact 생성됨
#
# total artifacts: 22450
# task_id: session-20250930-060607-59984faf
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit logins.date_last_filled to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit insecure_credentials.create_time to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:48:01] DataEncoder - Converted WebKit keywords.last_modified to datetime
# 총 70479개의 artifact 생성됨
#
# total artifacts: 70479

# %% [markdown]
# ## 메모리 사용량 확인

# %%
import sys

# result = make_test_artifacts("session-20250930-060607-59984faf")
# result = make_test_artifacts("session-20251002-052932-151e52e9")
result = make_test_artifacts("session-20251002-045744-53bf2115")

# 메모리 사용량 확인
memory_usage = sys.getsizeof(result) / (1024 * 1024)  # MB 단위
print(f"artifact_list 메모리 사용량: {memory_usage:.2f} MB")
print(f"총 artifact 개수: {len(result):,}개")
print(f"평균 artifact 크기: {sys.getsizeof(result) / len(result) / 1024:.2f} KB")
# Out:
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit logins.date_last_filled to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit insecure_credentials.create_time to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit logins.date_last_filled to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit cookies.creation_utc to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit cookies.last_access_utc to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit cookies.expires_utc to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit cookies.last_update_utc to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit keywords.last_modified to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit urls.last_visit_time to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit visits.visit_time to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit downloads.start_time to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit downloads.end_time to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit downloads.last_access_time to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit logins.date_created to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit logins.date_last_used to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit logins.date_received to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit logins.date_password_modified to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit logins.date_last_filled to datetime
# [2025-10-13 11:44:57] DataEncoder - Cookies failed
# [2025-10-13 11:44:57] DataEncoder - Converted Unix autofill.date_created to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted Unix autofill.date_last_used to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit keywords.date_created to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit keywords.last_visited to datetime
# [2025-10-13 11:44:57] DataEncoder - Converted WebKit keywords.last_modified to datetime
# 총 96862개의 artifact 생성됨
#
# artifact_list 메모리 사용량: 0.83 MB
# 총 artifact 개수: 96,862개
# 평균 artifact 크기: 0.01 KB

# %%
import datetime
def date_from_webkit(webkit_timestamp):
    epoch_start = datetime.datetime(1601,1,1)
    delta = datetime.timedelta(microseconds=int(webkit_timestamp))
    return epoch_start + delta

def check_date_from_now(webkit_timestamp, month: int) -> bool:
    """Webkit timestamp가 현재로부터 month개월 이내인지 확인"""
    if not isinstance(webkit_timestamp, (int, float)):
        return False
    if webkit_timestamp <= 0:
        return False
    
    # # ✅ Webkit 타임스탬프 범위 검증 (1601년 ~ 3000년 정도)
    # if webkit_timestamp < 0 or webkit_timestamp > 50000000000000000:  # 약 3000년
    #     return False
    
    try:
        data_time = date_from_webkit(webkit_timestamp)
        target_time = datetime.datetime.now() - datetime.timedelta(weeks=month * 4)
        return target_time < data_time
    except (ValueError, OverflowError):
        print("!!!")
        return False

def check_timestamp_from_now(timestamp, month: int) -> bool:
    """Unix timestamp가 현재로부터 month개월 이내인지 확인"""
    if not isinstance(timestamp, (int, float)):
        return False
    if timestamp <= 0:
        return False
    
    try:
        data_time = datetime.datetime.fromtimestamp(timestamp)
        target_time = datetime.datetime.now() - datetime.timedelta(weeks=month * 4)
        return target_time < data_time
    except (ValueError, OSError):  # 잘못된 timestamp 값
        return False


stat = {}

now_type = ""
for i, artifact in enumerate(result, 1):
    if now_type != artifact["artifact_type"]:
        now_type = str(artifact["artifact_type"])
        if now_type == "search_directories":
            continue
        print(now_type)
        stat.update({now_type: [0, 0]})
        keys = list(artifact["data"].keys())
        # keys = [key for key in keys if isinstance(key, str) and key.find("date") >= 0 or key.find("time") >= 0]
        for key in keys:
            print(key, artifact["data"][key], end=",")
        
        timestamp = None
        timestamps = [key for key in keys if key.find("timestamp") >= 0]
        if timestamps:
            timestamp = timestamps[0]
        print()

    if not keys:
        continue

    if now_type == "prefetch_files":
        stat[now_type][0] += 1
        try:
            last_run_time = datetime.datetime.strptime(
                artifact["data"][keys[0]], 
                "%Y-%m-%dT%H:%M:%SZ"
            )
            target_time = datetime.datetime.now() - datetime.timedelta(weeks=12)  # 3개월 = 12주
            if target_time < last_run_time:
                stat[now_type][1] += 1
        except (ValueError, KeyError, TypeError):
            print("!")
            pass  # 파싱 실패 시 스킵
        continue

    if now_type == "usb_devices":
        stat[now_type][0] += 1
        continue
    
    if now_type.find("chrome") < 0 and now_type.find("edge") < 0:
        if not timestamp:
            continue

        time = artifact["data"].get(timestamp)
        if not time:
            continue

        stat[now_type][0] += 1
        if check_timestamp_from_now(time, 6):
            stat[now_type][1] += 1
        continue

    try:
        time_value = int(artifact["data"][keys[-1]])
        stat[now_type][0] += 1
        if check_date_from_now(time_value, 3):
            stat[now_type][1] += 1
    except (ValueError, KeyError, TypeError):
        pass  # 변환 실패 시 스킵

for k, v in stat.items():
    print(str(k).ljust(20), end=" ")
    print(f"total data: {str(v[0]).ljust(5)}, in-time data: {v[1]}")
# Out:
# chrome.urls
# id 53,url https://colab.research.google.com/notebooks/welcome.ipynb#scrollTo=lSrWNr3MuFUS,title Colab 시작하기 - Colab,hidden 0,typed_count 0,visit_count 6,last_visit_time 2025-09-24 07:43:47+00:00,
# chrome.visits
# id 53449,url 26316,app_id ,from_visit 0,segment_id 0,transition 805306368,visit_time 2025-07-04 05:47:50+00:00,opener_visit 53450,visit_duration 0,visited_link_id 0,is_known_to_sync 1,originator_visit_id 21978,external_referrer_url https://www.naver.com/,originator_cache_guid suZG25Nz7o6aW3duZPhpMA==,originator_from_visit 0,originator_opener_visit 21977,consider_for_ntp_most_visited 1,incremented_omnibox_typed_score 0,
# chrome.downloads
# id 1,etag "67cb13bb-d127cdf4",guid cbcb0d3f-7ae8-4415-a1ac-2f3934acab80,hash ,state 1,opened 1,tab_url https://www.kali.org/get-kali/#kali-virtual-machines,end_time 2025-04-02 00:20:24+00:00,referrer https://www.kali.org/,site_url ,by_ext_id ,mime_type application/x-compressed,transient 0,start_time 2025-04-02 00:17:45+00:00,by_ext_name ,danger_type 0,http_method ,target_path C:\Users\KISIA\Downloads\kali-linux-2025.1a-vmware-amd64.7z,total_bytes 3509046772,current_path C:\Users\KISIA\Downloads\kali-linux-2025.1a-vmware-amd64.7z,by_web_app_id ,last_modified Fri, 07 Mar 2025 15:41:47 GMT,received_bytes 3509046772,interrupt_reason 0,last_access_time 2025-04-02 00:20:26+00:00,tab_referrer_url https://www.google.com/,original_mime_type application/x-7z-compressed,embedder_download_data
#
# ,
# chrome.visited_links
# id 4634,frame_url https://www.notion.so/,link_url_id 529,visit_count 22,top_level_url https://www.notion.so/S-1b5196e096c880519907c8e6cb4c9876?pvs=12,
# chrome.logins
# id 1,scheme 0,icon_url ,form_data ,action_url ,origin_url https://profile.broadcom.com/,times_used 0,sender_name ,date_created 2025-04-02 00:24:21+00:00,display_name ,sender_email ,signon_realm https://profile.broadcom.com/,date_received 1601-01-01 00:00:00+00:00,password_type 0,date_last_used 1601-01-01 00:00:00+00:00,federation_url ,password_value ,submit_element ,username_value ,skip_zero_click 0,date_last_filled 1601-01-01 00:00:00+00:00,password_element ,username_element ,moving_blocked_for ,blacklisted_by_user 1,keychain_identifier ,date_password_modified 1601-01-01 00:00:00+00:00,possible_username_pairs ,generation_upload_status 0,sender_profile_image_url ,sharing_notification_displayed 0,
# chrome.autofill
# name mtcap-statusimg-1,count 1,value ,value_lower ,date_created 2025-04-02 00:21:51+00:00,date_last_used 2025-04-02 00:21:51+00:00,
# chrome.keywords
# id 2,url {google:baseURL}search?q={searchTerms}&{google:RLZ}{google:originalQueryForSuggestion}{google:assistedQueryStats}{google:searchFieldtrialParameter}{google:language}{google:prefetchSource}{google:searchClient}{google:sourceId}{google:contextualSearchVersion}ie={inputEncoding},keyword google.com,url_hash v20�)�*�af:�AȕO��:<50�ƌ�����ߧʲD��V��Bה�*JcM�";,�M��Uڢ�Cf,image_url {google:baseSearchByImageURL}upload,is_active 0,sync_guid 580fa3c4-63ec-4404-ab29-25d7f404281c,short_name Google,favicon_url https://www.google.com/images/branding/product/ico/googleg_alldp.ico,new_tab_url ,suggest_url {google:baseSuggestURL}search?{google:searchFieldtrialParameter}client={google:suggestClient}&gs_ri={google:suggestRid}&xssi=t&q={searchTerms}&{google:inputType}{google:omniboxFocusType}{google:cursorPosition}{google:currentPageUrl}{google:pageClassification}{google:clientCacheTimeToLive}{google:searchVersion}{google:sessionToken}{google:prefetchQuery}sugkey={google:suggestAPIKeyParameter},usage_count 0,date_created 1601-01-01 00:00:00+00:00,last_visited 1601-01-01 00:00:00+00:00,last_modified 1601-01-01 00:00:00+00:00,alternate_urls ["{google:baseURL}#q={searchTerms}","{google:baseURL}search#q={searchTerms}","{google:baseURL}webhp#q={searchTerms}","{google:baseURL}s#q={searchTerms}","{google:baseURL}s?q={searchTerms}"],prepopulate_id 1,input_encodings UTF-8,originating_url ,starter_pack_id 0,created_by_policy 0,enforced_by_policy 0,featured_by_policy 0,safe_for_autoreplace 1,created_from_play_api 0,image_url_post_params encoded_image={google:imageThumbnail},image_url={google:imageURL},sbisrc={google:imageSearchSource},original_width={google:imageOriginalWidth},original_height={google:imageOriginalHeight},processed_image_dimensions={google:processedImageDimensions},search_url_post_params ,suggest_url_post_params ,
# edge.urls
# id 62,url http://www.msftconnecttest.com/redirect,title ::::: olleh WiFi redirection page :::::,hidden 0,typed_count 0,visit_count 8,last_visit_time 2025-09-30 06:19:16+00:00,
# edge.visits
# id 18168,url 14012,app_id ,from_visit 0,segment_id 0,transition 805306374,visit_time 2025-07-04 04:21:21+00:00,opener_visit 0,visit_duration 1425001292,visited_link_id 0,is_known_to_sync 0,originator_visit_id 0,external_referrer_url ,originator_cache_guid ,originator_from_visit 0,originator_opener_visit 0,consider_for_ntp_most_visited 1,incremented_omnibox_typed_score 0,
# edge.downloads
# id 1,etag "40a72e5-aca609a6",guid 17297432-17c8-4440-a5d4-206136eebcb5,hash ,state 1,opened 1,tab_url https://www.google.com/intl/ko/chrome/,end_time 2025-04-01 04:38:33+00:00,referrer https://www.google.com/,site_url ,by_ext_id ,mime_type application/x-msdownload,transient 0,start_time 2025-04-01 04:38:31+00:00,by_ext_name ,danger_type 4,http_method ,target_path C:\Users\KISIA\Downloads\ChromeSetup.exe,total_bytes 10781056,current_path C:\Users\KISIA\Downloads\ChromeSetup.exe,by_web_app_id ,last_modified Tue, 25 Mar 2025 20:27:52 GMT,received_bytes 10781056,interrupt_reason 0,last_access_time 2025-04-01 04:38:35+00:00,tab_referrer_url https://www.bing.com/,original_mime_type application/x-msdos-program,embedder_download_data
#
# ,
# edge.visited_links
# id 265,frame_url https://www.bing.com/,link_url_id 14393,visit_count 1,top_level_url https://www.bing.com/search?q=d&form=WSBEDG&qs=SW&cvid=7d878c4282364c1daf2f2400c42de544&pq=d&cc=KR&setlang=ko-KR&nclid=A1FD7AF6A7423C2A242AB8B69AB04AB6&ts=1751781728163&nclidts=1751781728&tsms=163&wsso=Moderate,
# edge.logins
# id 1,scheme 0,icon_url ,form_data ,action_url ,origin_url https://profile.broadcom.com/,times_used 0,sender_name ,date_created 2025-04-02 00:24:21+00:00,display_name ,sender_email ,signon_realm https://profile.broadcom.com/,date_received 1601-01-01 00:00:00+00:00,password_type 0,date_last_used 1601-01-01 00:00:00+00:00,federation_url ,password_value v10
# 	�IV��*�3h�6"ʵ�A���&�3,submit_element ,username_value ,skip_zero_click 0,date_last_filled 1601-01-01 00:00:00+00:00,password_element ,username_element ,moving_blocked_for ,blacklisted_by_user 1,keychain_identifier ,date_password_modified 1601-01-01 00:00:00+00:00,possible_username_pairs ,generation_upload_status 0,sender_profile_image_url ,sharing_notification_displayed 0,
# edge.autofill
# name mtcap-statusimg-1,count 1,value ,value_lower ,date_created 2025-04-02 00:21:51+00:00,date_last_used 2025-04-02 00:21:51+00:00,
# edge.keywords
# id 2,url {bing:baseURL}search?q={searchTerms}&{bing:cvid}{bing:msb}{google:assistedQueryStats},keyword bing.com,url_hash v20�Qō}Д���>�axߍ�HJLF=��7Y�T�k2�}���6�F[`�bs9�%,image_url {bing:baseURL}images/detail/search?iss=sbiupload&FORM=ANCMS1#enterInsights,is_active 1,sync_guid 485bf7d3-0215-45af-87dc-538868000001,short_name Bing,favicon_url https://www.bing.com/sa/simg/favicon-trans-bg-blue-mg.ico,new_tab_url {bing:baseURL}chrome/newtab,suggest_url {bing:baseURL}qbox?query={searchTerms}&language={language}&{bing:partner}{bing:cvid}{bing:msb}{bing:ig}{bing:baseQuery}{google:inputType}{google:cursorPosition}{google:pageClassification}{bing:features}{bing:flights},usage_count 0,date_created 1601-01-01 00:00:00+00:00,last_visited 1601-01-01 00:00:00+00:00,last_modified 1601-01-01 00:00:00+00:00,alternate_urls [],prepopulate_id 1,input_encodings UTF-8,originating_url ,starter_pack_id 0,created_by_policy 0,enforced_by_policy 0,featured_by_policy 0,safe_for_autoreplace 1,created_from_play_api 0,image_url_post_params imageBin={google:imageThumbnailBase64},search_url_post_params ,suggest_url_post_params ,
# statistics
# mft_deleted_count 4711,recycle_bin_count 56,total_deleted_files 4767,total_mft_size_bytes 6.4457772025502824e+16,total_deleted_size_bytes 6.445777207410328e+16,total_recycle_bin_size_bytes 48600455,
# data_sources
# has_mft_data True,has_recycle_bin_data True,
# mft_deleted_files
# file_name Unknown_File_12,file_size 0.0,full_path ,file_index 1,access_time ,is_directory False,parse_status SUCCESS,creation_time ,deletion_time ,allocated_size 0.0,file_attributes 0x00000000,mft_record_number 12.0,modification_time ,parent_mft_record 0.0,access_time_timestamp 0.0,creation_time_timestamp 0.0,deletion_time_timestamp 0.0,modification_time_timestamp 0.0,
# recycle_bin_files
# user_sid S-1-5-21-2386800296-3450899104-3684993712-1001,file_index 1,deleted_time 2025-09-12T14:50:33Z,parse_status SUCCESS,original_path C:\Users\KISIA\Downloads\test_report.pdf,original_file_name test_report.pdf,original_file_size 362278.0,current_i_file_path C:/$Recycle.Bin/S-1-5-21-2386800296-3450899104-3684993712-1001/$I0ZG120.pdf,current_r_file_path C:/$Recycle.Bin/S-1-5-21-2386800296-3450899104-3684993712-1001/$R0ZG120.pdf,recycle_bin_version WIN10_PLUS,deleted_time_timestamp 1757688633340.0,
# lnk_files
# flags__has_name False,flags__has_arguments False,flags__has_link_info True,flags__has_working_dir True,flags__has_icon_location False,flags__has_relative_path True,flags__has_target_id_list True,header__hot_key 0,header__file_size 36684512,header__icon_index 0.0,header__link_clsid 0114020000000000C000000000000046,header__link_flags 524443.0,header__write_time 2025-04-14T07:49:21Z,header__access_time 2025-04-14T07:53:14Z,header__header_size 76,header__show_command 1,header__creation_time 2025-04-14T07:49:21Z,header__link_flags_hex 0x0008009b,header__write_time_raw 1dbad11bc13f7bc,header__access_time_raw 1dbad1246a92b3b,header__file_attributes 32,header__header_size_hex 0x0000004c,header__creation_time_raw 1dbad11bc042d04,header__file_attributes_hex 0x00000020,header__link_flags_formatted HasTargetIDList | HasLinkInfo | HasRelativePath | HasWorkingDir | IsUnicode,header__write_time_timestamp 1744616961.0,header__access_time_timestamp 1744617194.0,header__show_command_formatted 일반,header__creation_time_timestamp 1744616961.0,header__file_attributes_formatted ARCHIVE,file_name 010Editorp.exe - 바로 가기.lnk,file_path C:/Users/KISIA/Desktop/010Editorp.exe - 바로 가기.lnk,file_size 36684512,forensics__machine_id desktop-vdvjm1o,forensics__drive_serial 0x1ccd2b69,link_info__paths__local_base_path C:\Program Files\010 Editor\010Editorp.exe,link_info__offsets__volume_id_offset 28.0,link_info__offsets__local_base_path_offset 45.0,link_info__offsets__common_path_suffix_offset 88.0,link_info__offsets__common_network_relative_link_offset 0.0,link_info__volume_info__drive_type 3.0,link_info__volume_info__volume_id_size 17.0,link_info__volume_info__drive_serial_hex 0x1ccd2b69,link_info__volume_info__drive_serial_number 483208041.0,link_info__volume_info__volume_label_offset 16.0,link_info__volume_info__drive_type_formatted FIXED,link_info__link_info_size 89.0,link_info__link_info_flags 1.0,link_info__link_info_flags_hex 0x00000001,link_info__link_info_header_size 28.0,link_type__is_file_link True,link_type__is_directory_link False,file_index 1,string_data__relative_path ..\..\..\Program Files\010 Editor\010Editorp.exe,string_data__working_directory C:\Program Files\010 Editor,target_info__target_path C:\Program Files\010 Editor\010Editorp.exe,target_info__target_times__write 2025-04-14T07:49:21Z,target_info__target_times__access 2025-04-14T07:53:14Z,target_info__target_times__creation 2025-04-14T07:49:21Z,target_info__target_times__write_timestamp 1744616961.0,target_info__target_times__access_timestamp 1744617194.0,target_info__target_times__creation_timestamp 1744616961.0,target_info__target_exists True,target_info__target_file_size 36684512,target_info__target_file_attributes 32,target_info__target_file_attributes_formatted ARCHIVE,lnk_file_times__access 2025-09-07T13:25:22,lnk_file_times__creation 2025-04-14T16:49:21,lnk_file_times__modification 2025-04-14T16:49:21,lnk_file_times__access_timestamp 1757219122,lnk_file_times__creation_timestamp 1744616961,lnk_file_times__modification_timestamp 1744616961,string_data__description nan,string_data__icon_location nan,string_data__command_line_args nan,forensics__volume_label nan,link_info__volume_info__volume_label nan,
# discord.files
# created 2025-09-24T21:52:57,file_name app.ico,file_path C:/Users/KISIA/AppData/Local/Discord/app-1.0.9210/app.ico,file_size 285478,file_type 알수없음,file_index 1,is_valid_file True,last_modified 2025-05-06T01:43:30,relative_path app-1.0.9210/app.ico,messenger_type Discord,created_timestamp 1758718377559.0,last_modified_timestamp 1746463410000.0,
# kakaotalk.files
# created 2025-10-02T13:54:00,file_name session.json,file_path C:/Users/KISIA/AppData/Local/Kakao/KakaoTalk/.sentry-native/74c9a8a8-49c9-4751-9da6-975f28a4462b.run/session.json,file_size 287.0,file_type 설정파일,file_index 1,is_valid_file True,last_modified 2025-10-02T13:54:02,relative_path .sentry-native/74c9a8a8-49c9-4751-9da6-975f28a4462b.run/session.json,messenger_type KakaoTalk,created_timestamp 1759380840549.0,last_modified_timestamp 1759380842413.0,
# prefetch_files
# file_path C:/Windows/Prefetch/ABEX' CRACKME #1.EXE-4DCC377D.pf,file_size 4725.0,structure__run_count 11,structure__signature SCCA,structure__num_volumes 18488.0,structure__prefetch_hash 4dcc377d,structure__format_version 1f,last_run_times_1 2025-06-19T01:39:04Z,last_run_times_2 2025-06-19T01:30:10Z,last_run_times_3 2025-06-19T01:29:43Z,last_run_times_4 2025-06-19T01:27:56Z,last_run_times_5 2025-06-19T01:27:01Z,last_run_times_6 2025-06-19T01:25:06Z,last_run_times_7 2025-06-19T01:24:01Z,last_run_times_8 2025-06-19T01:21:55Z,structure__num_file_metrics 296,structure__num_trace_chains 1448,structure__volumes_info_size 1,structure__file_metrics_offset 0,structure__trace_chains_offset 36,structure__volumes_info_offset 4742.0,structure__executable_file_name ABEX' CRACKME #1.EXE,structure__executable_file_size 19774.0,structure__filename_strings_size 13584.0,structure__filename_strings_offset 1517.0,file_index 1,is_compressed True,parse_success True,execution_count 8,application_name ABEX' CRACKME #1.EXE,
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# usb_devices
# device_key FC137AD807AFB,volume_info__file_system N/A,volume_info__mount_point N/A,volume_info__volume_guid N/A,volume_info__drive_letter N/A,volume_info__volume_label N/A,data_sources__has_usb_data False,data_sources__has_usbstor_data False,data_sources__has_setupapi_data True,data_sources__has_event_viewer_data True,data_sources__has_device_classes_data True,data_sources__has_portable_device_data False,device_index 1,setupapi_info__product_id N/A,setupapi_info__volume_guid {53f56307-b6bf-11d0-94f2-00a0c91efb8b},setupapi_info__volume_name VendorC ProductCode,setupapi_info__user_account SWD\WPDBUSENUM,setupapi_info__serial_number FC137AD807AFB,setupapi_info__last_connection_time 2025/09/11 00:12:39.500,setupapi_info__first_connection_time 2025/09/11 00:12:39.500,setupapi_info__last_disconnection_time N/A,setupapi_info__first_connection_after_boot 2025/09/11 00:12:39.500,primary_source SetupAPI,device_metadata__vid_pid N/A,device_metadata__instance_id N/A,device_metadata__serial_number FC137AD807AFB,device_metadata__device_class_name VendorC ProductCode,connection_times__first_install_time N/A,connection_times__last_connection_time N/A,connection_times__first_connection_time N/A,connection_times__boot_after_connect_time N/A,connection_times__last_disconnection_time N/A,event_viewer_info [{"user_id": "S-1-5-18", "event_id": 10000, "thread_id": "17712", "event_time": "2025/09/11 04:41:42.255", "event_type": "Install", "process_id": "16636", "channel_name": "System", "service_name": "N/A", "provider_name": "Microsoft-Windows-DriverFrameworks-UserMode", "raw_event_data": "<Event xmlns='http://schemas.microsoft.com/win/2004/08/events/event'><System><Provider Name='Microsoft-Windows-DriverFrameworks-UserMode' Guid='{2e35aaeb-857f-4beb-a418-2e6c0e54d988}'/><EventID>10000</EventID><Version>1</Version><Level>4</Level><Task>48</Task><Opcode>1</Opcode><Keywords>0x2000000000000000</Keywords><TimeCreated SystemTime='2025-09-11T04:41:42.2551112Z'/><EventRecordID>23977</EventRecordID><Correlation/><Execution ProcessID='16636' ThreadID='17712'/><Channel>System</Channel><Computer>DESKTOP-VDVJM1O</Computer><Security UserID='S-1-5-18'/></System><UserData><UMDFDeviceInstallBegin xmlns='http://www.microsoft.com/DriverFrameworks/UserMode/Event'><DeviceId>SWD\\WPDBUSENUM\\_??_USBSTOR#DISK&amp;VEN_VENDORC&amp;PROD_PRODUCTCODE&amp;REV_3.20#FC137AD807AFB&amp;0#{53F56307-B6BF-11D0-94F2-00A0C91EFB8B}</DeviceId><FrameworkVersion>2.35.0</FrameworkVersion></UMDFDeviceInstallBegin></UserData></Event>", "event_record_id": "23977", "driver_file_name": "N/A", "device_description": "N/A", "device_instance_id": "SWD\\WPDBUSENUM\\_??_USBSTOR#DISK&VEN_VENDORC&PROD_PRODUCTCODE&REV_3.20#FC137AD807AFB&0#{53F56307-B6BF-11D0-94F2-00A0C91EFB8B}"}, {"user_id": "S-1-5-18", "event_id": 20003, "thread_id": "17712", "event_time": "2025/09/11 04:41:42.319", "event_type": "Remove", "process_id": "16636", "channel_name": "System", "service_name": "WUDFWpdFs", "provider_name": "Microsoft-Windows-UserPnp", "raw_event_data": "<Event xmlns='http://schemas.microsoft.com/win/2004/08/events/event'><System><Provider Name='Microsoft-Windows-UserPnp' Guid='{96f4a050-7e31-453c-88be-9634f4e02139}'/><EventID>20003</EventID><Version>0</Version><Level>4</Level><Task>7005</Task><Opcode>0</Opcode><Keywords>0x8000000000000000</Keywords><TimeCreated SystemTime='2025-09-11T04:41:42.3186987Z'/><EventRecordID>23980</EventRecordID><Correlation/><Execution ProcessID='16636' ThreadID='17712'/><Channel>System</Channel><Computer>DESKTOP-VDVJM1O</Computer><Security UserID='S-1-5-18'/></System><UserData><AddServiceID xmlns='http://manifests.microsoft.com/win/2004/08/windows/userpnp'><ServiceName>WUDFWpdFs</ServiceName><DriverFileName>\\SystemRoot\\system32\\DRIVERS\\WUDFRd.sys</DriverFileName><DeviceInstanceID>SWD\\WPDBUSENUM\\_??_USBSTOR#DISK&amp;VEN_VENDORC&amp;PROD_PRODUCTCODE&amp;REV_3.20#FC137AD807AFB&amp;0#{53F56307-B6BF-11D0-94F2-00A0C91EFB8B}</DeviceInstanceID><PrimaryService>true</PrimaryService><Up ...
# chrome.urls          total data: 0    , in-time data: 0
# chrome.visits        total data: 24106, in-time data: 0
# chrome.downloads     total data: 0    , in-time data: 0
# chrome.visited_links total data: 0    , in-time data: 0
# chrome.logins        total data: 371  , in-time data: 0
# chrome.autofill      total data: 0    , in-time data: 0
# chrome.keywords      total data: 0    , in-time data: 0
# edge.urls            total data: 0    , in-time data: 0
# edge.visits          total data: 25200, in-time data: 0
# edge.downloads       total data: 0    , in-time data: 0
# edge.visited_links   total data: 0    , in-time data: 0
# edge.logins          total data: 32   , in-time data: 0
# edge.autofill        total data: 0    , in-time data: 0
# edge.keywords        total data: 0    , in-time data: 0
# statistics           total data: 0    , in-time data: 0
# data_sources         total data: 0    , in-time data: 0
# mft_deleted_files    total data: 2779 , in-time data: 0
# recycle_bin_files    total data: 56   , in-time data: 0
# lnk_files            total data: 273  , in-time data: 118
# discord.files        total data: 2309 , in-time data: 0
# kakaotalk.files      total data: 6814 , in-time data: 0
# prefetch_files       total data: 251  , in-time data: 0
# usb_devices          total data: 13   , in-time data: 0

# %% [markdown]
# ## 메모리 최적화 버전 (제너레이터 사용)
# 대량 데이터를 한 번에 메모리에 올리지 않고 필요할 때마다 생성

# %%
def generate_artifacts(task_id: str, batch_size: int = 1000):
    """
    제너레이터 방식: 메모리 효율적으로 artifacts를 배치 단위로 생성
    
    Args:
        task_id: 작업 ID
        batch_size: 한 번에 반환할 artifacts 개수
        
    Yields:
        batch_size 개의 artifacts 리스트
    """
    white_list = ["urls", "visits", "visited_links", "keywords", "keywork_search_terms", 
                  "autofill", "downloads", "download_url_chains", "logins"]
    white_list_set = set()
    for i in white_list:
        white_list_set.update(("chrome."+i, "edge."+i))
    
    for category in Category:
        data = helper.get_encoded_results(task_id, category)
        
        for d in data.data:
            artifact_type = d.name.lower()
            
            if category == Category.BROWSER and artifact_type not in white_list_set:
                continue
            
            collected_at_str = datetime.datetime.now(tz=datetime.UTC).isoformat()
            
            # 대용량 데이터를 청크 단위로 처리
            total_rows = len(d.data)
            for start_idx in range(0, min(total_rows, 10000), batch_size):
                end_idx = min(start_idx + batch_size, total_rows, 10000)
                
                # 청크만 메모리에 로드
                chunk_records = d.data.iloc[start_idx:end_idx].to_dict('records')
                
                artifacts = [
                    {
                        "id": str(uuid.uuid4()),
                        "artifact_type": artifact_type,
                        "source": None,
                        "data": record,
                        "collected_at": collected_at_str
                    }
                    for record in chunk_records
                ]
                
                yield artifacts
                
        del data  # 메모리 해제


# 사용 예시 1: 배치 처리
def process_in_batches(task_id: str):
    """배치 단위로 처리 (예: DB에 저장)"""
    total_count = 0
    
    for batch in generate_artifacts(task_id, batch_size=1000):
        # 여기서 배치 단위로 DB 저장 또는 다른 처리
        total_count += len(batch)
        print(f"진행 중... 현재까지 {total_count:,}개 처리")
        
    print(f"\n총 {total_count:,}개 처리 완료")
    return total_count


# 사용 예시 2: 필요하면 전체 리스트로 변환
def make_test_artifacts_optimized(task_id: str) -> list:
    """메모리가 충분하면 전체를 리스트로 변환"""
    artifact_list = []
    
    for batch in generate_artifacts(task_id, batch_size=5000):
        artifact_list.extend(batch)
    
    print(f"\n총 {len(artifact_list):,}개의 artifact 생성됨")
    return artifact_list

# %% [markdown]
# ## 권장사항 정리
#
# ### 5만 개 데이터 처리 시:
#
# **1. 메모리가 충분한 경우 (8GB+ RAM)**
# - 현재 구현 그대로 사용 OK
# - 5만 개 × 평균 1-2KB = 약 50-100MB 정도 (문제없음)
#
# **2. DB에 바로 저장하는 경우**
# - 제너레이터 방식 사용 (`process_in_batches`)
# - 1000개씩 배치로 INSERT → 메모리 사용량 최소화
#
# **3. 데이터가 더 커질 가능성이 있는 경우**
# - 제너레이터 방식으로 미리 구현
# - 확장성 확보
#
# ### 추가 최적화 팁:
# - `data` 필드의 불필요한 컬럼 제거
# - JSON 직렬화 전 데이터 타입 최적화 (datetime → string 등)
# - `del` 키워드로 사용 후 명시적 메모리 해제 (현재 코드에 이미 있음 ✅)
